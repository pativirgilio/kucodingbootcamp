# %% [markdown]
# Create a Python script to perform a sentiment analysis of the Twitter activity of  __BBC, CBS, CNN, Fox, and New York times__.
#
# The first plot will be and/or feature the following:
#
# * Be a scatter plot of sentiments of the last __100__ tweets sent out by each news organization, ranging from -1.0 to 1.0, where a score of 0 expresses a neutral sentiment, -1 the most negative sentiment possible, and +1 the most positive sentiment possible.
# * Each plot point will reflect the _compound_ sentiment of a tweet.
# * Sort each plot point by its relative timestamp.
#
# The second plot will be a bar plot visualizing the _overall_ sentiments of the last 100 tweets from each organization. For this plot, you will again aggregate the compound sentiments analyzed by VADER.
#
# The tools of the trade you will need for your task as a data analyst include the following: tweepy, pandas, matplotlib, seaborn, textblob, and VADER.
#
# Your final Jupyter notebook must:
#
# * Pull last 100 tweets from each outlet.
# * Perform a sentiment analysis with the compound, positive, neutral, and negative scoring for each tweet.
# * Pull into a DataFrame the tweet's source acount, its text, its date, and its compound, positive, neutral, and negative sentiment scores.
# * Export the data in the DataFrame into a CSV file.
# * Save PNG images for each plot.

# %%
# Dependencies
import tweepy
import json
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
consumer_key = consumer_key
consumer_secret = consumer_secret
access_token = access_token
access_token_secret = access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Search Terms
target_users = ("@CNN", "@BBC", "@CBS", "@FOX", "@NYTIMES")

# %%
# Variables for holding sentiments
sentiments = []

# Counter
counter = 1

    # Loop through all target users
for user in target_users:

    # Variable for max_id
    oldest_tweet = None
               
    # Run search around each tweet
    public_tweets = api.search(user, count=100, result_type="recent", max_id=oldest_tweet)

    # Loop through all tweets
    for tweet in public_tweets["statuses"]:
        
        new_time = datetime.strptime(tweet["created_at"],"%a %b %d %H:%M:%S %z %Y")
        # Wed Apr 25 19:06:31 +0000 2018   
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        text = tweet['text']
        tweets_ago = counter

        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1


        # Add sentiments for each tweet into a list
        sentiments.append({"Date": new_time, 
                       "User": user,
                       "Compound": compound,
                       "Positive": pos,
                       "Negative": neu,
                       "Neutral": neg,
                       "Tweets Ago": counter,
                       "Tweet Text": text})

        # Add to counter 
        counter += 1


# Print the Sentiments
print(sentiments)
# Out:
# [{'Date': datetime.datetime(2018, 4, 29, 2, 11, 43, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': -0.2617, 'Positive': 0.0, 'Negative': 0.915, 'Neutral': 0.085, 'Tweets Ago': 1, 'Tweet Text': "@CNN Nothing to do but shake my head at all the Trumpsters &amp; how they got conned.  But they just don't get it."}, {'Date': datetime.datetime(2018, 4, 29, 2, 11, 43, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 2, 'Tweet Text': "@CNN Why can't these people from Central America obtain asylum in Mexico? They're already there."}, {'Date': datetime.datetime(2018, 4, 29, 2, 11, 42, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': 0.2942, 'Positive': 0.199, 'Negative': 0.691, 'Neutral': 0.11, 'Tweets Ago': 3, 'Tweet Text': '@cnn Oh Thank God, C-span is airing the correspondents dinner (without your insane host blabbering all over it.) Bye, bye!'}, {'Date': datetime.datetime(2018, 4, 29, 2, 11, 41, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': -0.5709, 'Positive': 0.094, 'Negative': 0.674, 'Neutral': 0.232, 'Tweets Ago': 4, 'Tweet Text': '@CNN When journalists start reporting like "real  journalists, they won\'t be so despised. Poll: 70% of Americans don\'t trust the media.'}, {'Date': datetime.datetime(2018, 4, 29, 2, 11, 41, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': -0.3802, 'Positive': 0.26, 'Negative': 0.317, 'Neutral': 0.424, 'Tweets Ago': 5, 'Tweet Text': '@KenPettigrew @CNN @realDonaldTrump Awesome! You’re all useless shitheads 👍'}, {'Date': datetime.datetime(2018, 4, 29, 2, 11, 41, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': -0.5106, 'Positive': 0.0, 'Negative': 0.377, 'Neutral': 0.623, 'Tweets Ago': 6, 'Tweet Text': '@CNN You’re a dick.'}, {'Date': datetime.datetime(2018, 4, 29, 2, 11, 40, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': -0.5267, 'Positive': 0.098, 'Negative': 0.677, 'Neutral': 0.226, 'Tweets Ago': 7, 'Tweet Text': 'RT @kazweida: Dear @CNN ,\n\nStop sending me notifications about the nationalist bullshit our banana republic dictator is spouting to a sea o…'}, {'Date': datetime.datetime(2018, 4, 29, 2, 11, 40, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': 0.4404, 'Positive': 0.263, 'Negative': 0.627, 'Neutral': 0.11, 'Tweets Ago': 8, 'Tweet Text': '@CNN @CNNOpinion You assert one clear truth in this ,white male fears of their shrinking status, +their retreat to… https://t.co/bMVMNMI96O'}, {'Date': datetime.datetime(2018, 4, 29, 2, 11, 39, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': -0.2942, 'Positive': 0.0, 'Negative': 0.886, 'Neutral': 0.114, 'Tweets Ago': 9, 'Tweet Text': "RT @SparkleSoup45: 💥MEDIA SILENT on Lawsuit Alleging Major Clinton Campaign Finance Law Violations!💥\n\nWhatsamatter MSM?\nTHIS isn't newswort…"}, {'Date': datetime.datetime(2018, 4, 29, 2, 11, 38, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': -0.4374, 'Positive': 0.11, 'Negative': 0.677, 'Neutral': 0.213, 'Tweets Ago': 10, 'Tweet Text': "@CNN Then stop acting fools and get your act together!! Nobody trusts the MSM anymore and yall can't seen to figure… https://t.co/vuEwZXr7xN"}, {'Date': datetime.datetime(2018, 4, 29, 2, 11, 38, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': -0.5267, 'Positive': 0.098, 'Negative': 0.669, 'Neutral': 0.232, 'Tweets Ago': 11, 'Tweet Text': '@jumba47 @CNN @CNN: "South Korea credits Trump for opening door to talks with North."\nIt seems you\'re just a sore loser.'}, {'Date': datetime.datetime(2018, 4, 29, 2, 11, 38, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': -0.4299, 'Positive': 0.123, 'Negative': 0.634, 'Neutral': 0.243, 'Tweets Ago': 12, 'Tweet Text': '@CNN YET “JOURNALISTS” CAN SPREAD LIES AND POLITICAL PROPAGANDA AGAINST THOSE THEY OPPOSE IS ALL GOOD?? GET A LIFE!!👎🏼👎🏼👎🏼'}, {'Date': datetime.datetime(2018, 4, 29, 2, 11, 37, tzinfo=datetime.timezone.utc), 'User': '@CNN', 'Compound': 0.0,  ...

# %%
 # Append results to 'results_list'
sentiments_pd = pd.DataFrame.from_dict(sentiments).set_index('User').round(3)
sentiments_pd
# Out:
#           Compound                      Date  Negative  Neutral  Positive  \
# User
# @CNN        -0.262 2018-04-29 02:11:43+00:00     0.915    0.085     0.000
# @CNN         0.000 2018-04-29 02:11:43+00:00     1.000    0.000     0.000
# @CNN         0.294 2018-04-29 02:11:42+00:00     0.691    0.110     0.199
# @CNN        -0.571 2018-04-29 02:11:41+00:00     0.674    0.232     0.094
# @CNN        -0.380 2018-04-29 02:11:41+00:00     0.317    0.424     0.260
# @CNN        -0.511 2018-04-29 02:11:41+00:00     0.377    0.623     0.000
# @CNN        -0.527 2018-04-29 02:11:40+00:00     0.677    0.226     0.098
# @CNN         0.440 2018-04-29 02:11:40+00:00     0.627    0.110     0.263
# @CNN        -0.294 2018-04-29 02:11:39+00:00     0.886    0.114     0.000
# @CNN        -0.437 2018-04-29 02:11:38+00:00     0.677    0.213     0.110
# @CNN        -0.527 2018-04-29 02:11:38+00:00     0.669    0.232     0.098
# @CNN        -0.430 2018-04-29 02:11:38+00:00     0.634    0.243     0.123
# @CNN         0.000 2018-04-29 02:11:37+00:00     1.000    0.000     0.000
# @CNN        -0.475 2018-04-29 02:11:36+00:00     0.808    0.192     0.000
# @CNN        -0.860 2018-04-29 02:11:36+00:00     0.641    0.359     0.000
# @CNN        -0.296 2018-04-29 02:11:36+00:00     0.833    0.167     0.000
# @CNN        -0.735 2018-04-29 02:11:36+00:00     0.772    0.228     0.000
# @CNN        -0.542 2018-04-29 02:11:35+00:00     0.667    0.238     0.095
# @CNN         0.434 2018-04-29 02:11:34+00:00     0.889    0.000     0.111
# @CNN         0.000 2018-04-29 02:11:33+00:00     1.000    0.000     0.000
# @CNN         0.000 2018-04-29 02:11:33+00:00     1.000    0.000     0.000
# @CNN         0.494 2018-04-29 02:11:33+00:00     0.625    0.111     0.264
# @CNN         0.000 2018-04-29 02:11:33+00:00     1.000    0.000     0.000
# @CNN        -0.331 2018-04-29 02:11:32+00:00     0.811    0.127     0.062
# @CNN        -0.687 2018-04-29 02:11:32+00:00     0.779    0.221     0.000
# @CNN         0.000 2018-04-29 02:11:31+00:00     1.000    0.000     0.000
# @CNN         0.000 2018-04-29 02:11:31+00:00     1.000    0.000     0.000
# @CNN         0.750 2018-04-29 02:11:31+00:00     0.796    0.000     0.204
# @CNN        -0.128 2018-04-29 02:11:31+00:00     0.744    0.140     0.116
# @CNN         0.077 2018-04-29 02:11:31+00:00     0.779    0.104     0.117
# ...            ...                       ...       ...      ...       ...
# @NYTIMES     0.000 2018-04-29 02:08:21+00:00     1.000    0.000     0.000
# @NYTIMES    -0.649 2018-04-29 02:08:19+00:00     0.751    0.249     0.000
# @NYTIMES     0.000 2018-04-29 02:08:19+00:00     1.000    0.000     0.000
# @NYTIMES    -0.649 2018-04-29 02:08:18+00:00     0.777    0.223     0.000
# @NYTIMES     0.000 2018-04-29 02:08:15+00:00     1.000    0.000     0.000
# @NYTIMES    -0.765 2018-04-29 02:08:14+00:00     0.680    0.320     0.000
# @NYTIMES     0.000 2018-04-29 02:08:06+00:00     1.000    0.000     0.000
# @NYTIMES     0.000 2018-04-29 02:08:05+00:00     1.000    0.000     0.000
# @NYTIMES     0.000 2018-04-29 02:08:04+00:00     1.000    0.000     0.000
# @NYTIMES     0.000 2018-04-29 02:08:01+00:00     1.000    0.000     0.000
# @NYTIMES    -0.649 2018-04-29 02:08:00+00:00     0.751    0.249     0.000
# @NYTIMES     0.000 2018-04-29 02:07:52+00:00     1.000    0.000     0.000
# @NYTIMES     0.000 2018-04-29 02:07:52+00:00     1.000    0.000     0.000
# @NYTIMES     0.440 2018-04-29 02:07:51+00:00     0.884    0.000     0.116
# @NYTIMES    -0.382 2018-04-29 02:07:47+00:00     0.874    0.126     0.000
# @NYTIMES     0.000 2018-04-29 02:07:46+00:00     1.000    0.000     0.000
# @NYTIMES     0.000 2018-04-29 02:07:45+00:00     1.000    0.000     0.000
# @NYTIMES     0.440 2018-04-29 02:07:44+00:00     0.892    0.000     0.108
# @NYTIMES     0.000 2018-04-29 02:07:39+00:00     1.000    0.000     0.000
# @NYTIMES     0.340 2018-04-29 02:07:38+00:00     0.876    0.000     0.124
# @NYTIMES     0.000 2018-04-29 02:07:35+00:00     1.000    0.000     0.000
# @NYTIMES    -0.649 2018-04-29 02:07:31+00:00     0.751    0.249     0.000
# @NYTIMES     0.340 2018-04-29 02:07:26+00:00     0.902    0.000     0.098
# @NYTIMES     0.542 2018-04-29 02:07:20+00:00     0.800    0.000     0.200
# @NYTIMES     0.000 2018-04-29 02:07:10+00:00     1.000    0.000     0.000
# @NYTIMES     0.000 2018-04-29 02:07:01+00:00     1.000    0.000     0.000
# @NYTIMES     0.000 2018-04-29 02:07:01+00:00     1.000    0.000     0.000
# @NYTIMES    -0.625 2018-04-29 02:06:59+00:00     0.453    0.337     0.210
# @NYTIMES    -0.649 2018-04-29 02:06:56+00:00     0.777    0.223     0.000
# @NYTIMES     0.000 2018-04-29 02:06:55+00:00     1.000    0.000     0.000
#
#                                                  Tweet Text  Tweets Ago
# User
# @CNN      @CNN Nothing to do but shake my head at all th...           1
# @CNN      @CNN Why can't these people from Central Ameri...           2
# @CNN      @cnn Oh Thank God, C-span is airing the corres...           3
# @CNN      @CNN When journalists start reporting like "re...           4
# @CNN      @KenPettigrew @CNN @realDonaldTrump Awesome! Y...           5
# @CNN                                    @CNN You’re a dick.           6
# @CNN      RT @kazweida: Dear @CNN ,\n\nStop sending me n...           7
# @CNN      @CNN @CNNOpinion You assert one clear truth in...           8
# @CNN      RT @SparkleSoup45: 💥MEDIA SILENT on Lawsuit Al...           9
# @CNN      @CNN Then stop acting fools and get your act t...          10
# @CNN      @jumba47 @CNN @CNN: "South Korea credits Trump...          11
# @CNN      @CNN YET “JOURNALISTS” CAN SPREAD LIES AND POL...          12
# @CNN      RT @dawnparagracias: @CNN That time Trump decl...          13
# @CNN      @DottieFincham @Linington1971 @brandongroeny @...          14
# @CNN      RT @CharlesOrtel: which happens faster: Hell f...          15
# @CNN      Democrats need to stop believing this myth abo...          16
# @CNN      RT @CNN: "An attack on any journalist is an at...          17
# @CNN      RT @Redpainter1: Hi, @MSNBC \n\nWhy are you gu...          18
# @CNN      RT @CNN: President Trump speaks at a rally in ...          19
# @CNN      RT @CNN: "The Daily Show" contributor Michelle...          20
# @CNN                                     @chfortrump @CNN 🤡          21
# @CNN      @AmericanTrue7 @LawyerUp22 @SaraCarterDC @FCC ...          22
# @CNN      @TurnerBrennecke @CNN I didn't say it was.  I ...          23
# @CNN      RT @StevePieczenik: wondering why I lost 35 fo...          24
# @CNN      @CNN don't ever go please, i see daddy gave @P...          25
# @CNN      @MarilynCaracoz3 @ttblows @CNN I see him for w...          26
# @CNN      @nyambol @tamiurbandale @tommyboy41161 @Philli...          27
# @CNN      RT @CNN: "Hannity is a very wealthy man. So is...          28
# @CNN      @CNN when journalists attract with #FakeNews, ...          29
# @CNN      @CNN Trump said he'd run into a school under f...          30
# ...                                                     ...         ...
# @NYTIMES  RT @LorenaOchoaD1: @RojoJosele @Jacqueline2906...         471
# @NYTIMES  RT @nytimes: Larry Harvey, the Man Behind Burn...         472
# @NYTIMES  @cnni @BBCWorld @CNBC @washingtonpost @nytimes...         473
# @NYTIMES  RT @xeni: Larry Harvey, the Man Behind Burning...         474
# @NYTIMES  RT @fitlad_ml: @TrinityNYC @masakotoroji @nyti...         475
# @NYTIMES  Job Description for the Dumbest Job Ever   via...         476
# @NYTIMES  RT @TrinityNYC: セクシャルハラスメントや性差別が蔓延していたナイキ社。人事部...         477
# @NYTIMES  RT @nytimes: Six months ago, a parks official ...         478
# @NYTIMES  RT @nytimes: For too many women, life inside N...         479
# @NYTIMES  RT @nytimes: Speaker Paul Ryan’s decision to d...         480
# @NYTIMES  RT @nytimes: Larry Harvey, the Man Behind Burn...         481
# @NYTIMES  RT @AriFleischer: “A spokeswoman for Mr. Teste...         482
# @NYTIMES  RT @nytimes: Six months ago, a parks official ...         483
# @NYTIMES  RT @de1ong: @TomLevenson @nytimes @delong But ...         484
# @NYTIMES  RT @satgurukadass: #SaviorOfTheWorld\n Incarna...         485
# @NYTIMES  @nytimes Maybe you should put some resources o...         486
# @NYTIMES  RT @nytimes: One parent, on Paris: They might ...         487
# @NYTIMES  RT @nytimes: In the corridors of American powe...         488
# @NYTIMES  @cnn @msnbc @maddow @CNNPolitics @ABCPolitics ...         489
# @NYTIMES  RT @TerrinaMajnoona: @nytimes Is the "Hamas le...         490
# @NYTIMES  RT @nytimes: Six months ago, a parks official ...         491
# @NYTIMES  RT @nytimes: Larry Harvey, the Man Behind Burn...         492
# @NYTIMES  RT @jonathanweisman: As part of the team that ...         493
# @NYTIMES  RT @GlennKesslerWP: As Two Koreas Talk Peace, ...         494
# @NYTIMES  RT @joboaler: At Nike, Revolt Led by Women Lea...         495
# @NYTIMES  RT @AriFleischer: “A spokeswoman for Mr. Teste...         496
# @NYTIMES  The Most Unpopular Dog in Germany   via @NYTim...         497
# @NYTIMES  @pettyhazza @bakkoushmalik @im_PULSE @nytimes ...         498
# @NYTIMES  RT @xeni: Larry Harvey, the Man Behind Burning...         499
# @NYTIMES  RT @nytimes: Six months ago, a parks official ...         500
#
# [500 rows x 7 columns]

# %%
average_mood = sentiments_pd.groupby("User")["Compound"].mean()
print(average_mood)
# Out:
# User
# @BBC        0.14744
# @CBS        0.14549
# @CNN       -0.20841
# @FOX       -0.04962
# @NYTIMES   -0.01960
# Name: Compound, dtype: float64

# %% [markdown]
# PLOT 1:
# Scatter plot of sentiments of the last 100 tweets sent out by each news organization, ranging from -1.0 to 1.0, where a score of 0 expresses a neutral sentiment, -1 the most negative sentiment possible, and +1 the most positive sentiment possible.
# Each plot point will reflect the compound sentiment of a tweet.
# Sort each plot point by its relative timestamp.

# %%
#Export dataframe to csv:
sentiments_pd.to_csv("Twitter_News_Mood.csv", index=False)

# %%
#checking np.arange array for use on next cell
x_axis = np.arange(0,len(target_users))
x_axis
# Out:
# array([0, 1, 2, 3, 4])

# %%
# set the colors
colors=['b', 'g', 'r', 'y', 'm']

plt.style.use('dark_background')
# Loopthrough target_users to build a scatterplot using 'np.arange' by 
# creating an array of values starting from the the first tweet up to the last one.

for x in np.arange(0,len(target_users)):
    news_mood = sentiments_pd.loc[sentiments_pd["User"]==target_users[x]]
    #Sorting based on the time the tweet was posted. Latest tweet first, 100th tweet last. 
    news_mood = news_mood.sort_values("Tweets Ago")
    
    # Now, create an array of compound scores and associate each with a color 
    #  and make the source (target_users[x]) the same color for the legend. 
    
    plt.scatter(np.arange(len(news_mood["Compound"])), 
            news_mood["Compound"], color = colors[x],
            marker="x",label= target_users[x])

plt.legend(bbox_to_anchor = (1,1), title = 'News Source')        

#Add title, x axis label, y axis label, grid
plt.title(f"Sentiment Analysis of Tweets {datetime.now().strftime('%Y-%m-%d %H:%M')}")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.grid(True)

plt.savefig("Sentiment Analysis of Media Tweets")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'User'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-49bfafdfad7b> in <module>()
#       7
#       8 for x in np.arange(0,len(target_users)):
# ----> 9     news_mood = sentiments_pd.loc[sentiments_pd["User"]==target_users[x]]
#      10     #Sorting based on the time the tweet was posted. Latest tweet first, 100th tweet last.
#      11     news_mood = news_mood.sort_values("Tweets Ago")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'User'

# %% [markdown]
# The second plot is a bar plot visualizing the overall sentiments of the last 100 tweets from each news source. For this plot, I'm showing the aggregated compound sentiments analyzed by VADER.

# %%
# set the colors
colors=['b', 'g', 'r', 'y', 'm']

plt.style.use('ggplot')
#Loop through target_users to build a scatterplot.
# To get different legend colors for each source you need to loop through using 'np.arange' by 
# create an array of values starting from the the first tweet and incrementally 
# going up in a step wise fashion to get the last tweet. 

for i in np.arange(0,len(target_users)):
    news_mood = sentiments_pd.loc[sentiments_pd["User"]==target_users[i]]
    #Sorting based on the time the tweet was posted. Latest tweet first, 100th tweet last. 
    news_mood = news_mood.sort_values("Tweets Ago")
    
    # Now, create an array of compound scores and associate each with a color 
    #  and make the source (target_users[i]) the same color for the legend. 
    # And, add some styling so the color stands out. 
    plt.scatter(np.arange(len(news_mood["Compound"])), 
            news_mood["Compound"], color = colors[i],
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8,label= target_users[i])
#     plt.scatter(news_mood["Tweets Ago"],news_mood["Compound"], label = user, color = colors)

plt.legend(bbox_to_anchor = (1,1), title = 'News Source')        

#Add title, x axis label, y axis label, grid
plt.title(f"Sentiment Analysis of Tweets {datetime.now().strftime('%Y-%m-%d %H:%M')}")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.grid(True)

plt.savefig("Sentiment Analysis of Media Tweets")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3345dba98afe> in <module>()
#       2 colors=['b', 'g', 'r', 'y', 'm']
#       3
# ----> 4 plt.style.use('ggplot')
#       5 #Loop through target_users to build a scatterplot.
#       6 # To get different legend colors for each source you need to loop through using 'np.arange' by
#
# NameError: name 'plt' is not defined
